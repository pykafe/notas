# %%
import pandas as pd
import matplotlib
import string
# %matplotlib inline

# %%
countries = ['Timor-Leste','Portugal', 'Indonesia', 'UK', 'US']
populations =  [1296311, 10329506, 263991379, 66181585, 324459463]
area =  [129600000, 103200000, 2639900000, 661800000, 3244500000]

stats = {'Populatons': populations,
         'Area': area,}

data_frame = pd.DataFrame(stats, index=countries)
data_frame
# Out:
#                    Area  Populatons
# Timor-Leste   129600000     1296311
# Portugal      103200000    10329506
# Indonesia    2639900000   263991379
# UK            661800000    66181585
# US           3244500000   324459463

# %%
data_frame.plot(kind='bar')

# %%
countries = ['Timor-Leste','Portugal', 'Indonesia', 'UK', 'US']
populations =  [1296311, 10329506, 263991379, 66181585, 324459463]
area =  [129600000, 103200000, 2639900000, 661800000, 3244500000]
GDP = [2727, 202770, 1020515, 2496757, 19417144]

stats = {'Populatons': populations, 'Area': area, 'GDP': GDP}

data_frame = pd.DataFrame(stats, index=countries)
data_frame
# Out:
#                    Area       GDP  Populatons
# Timor-Leste   129600000      2727     1296311
# Portugal      103200000    202770    10329506
# Indonesia    2639900000   1020515   263991379
# UK            661800000   2496757    66181585
# US           3244500000  19417144   324459463

# %%
data_frame.plot(kind='bar')
data_frame.plot.pie(subplots=True, figsize=(18, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff37090c908>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff3707f3d68>], dtype=object)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d7a97e2d5b9c> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#       3
#       4 import pandas as pd
#       5 import numpy as np
#
# ImportError: No module named 'plotly'
